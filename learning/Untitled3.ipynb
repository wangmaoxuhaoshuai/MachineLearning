# %%
from Homework import main
# Out:
# Please enter a number as the length of random list (0 for quit!): 10
# 4
# 9
# 7
# 3
# 0
# 9
# 5
# 7
# 1
# 5
# Please choose a sort for list('b' for bubble sort,'q' for quick sort,'m' for '---'): b
# The result is >>>
# 0
# 1
# 3
# 4
# 5
# 5
# 7
# 7
# 9
# 9
# Please enter a number as the length of random list (0 for quit!): 10
# 8
# 4
# 5
# 4
# 3
# 7
# 2
# 2
# 1
# 6
# Please choose a sort for list('b' for bubble sort,'q' for quick sort,'m' for '---'): q
# The result is >>>
# 1
# 2
# 2
# 3
# 4
# 4
# 5
# 6
# 7
# 8
# Please enter a number as the length of random list (0 for quit!): 20
# 3
# 9
# 9
# 9
# 1
# 5
# 8
# 6
# 8
# 2
# 7
# 7
# 5
# 2
# 2
# 9
# 5
# 4
# 8
# 6
# Please choose a sort for list('b' for bubble sort,'q' for quick sort,'m' for '---'): f
# Please choose a sort for list('b' for bubble sort,'q' for quick sort,'m' for '---'): f
# Please choose a sort for list('b' for bubble sort,'q' for quick sort,'m' for '---'): q
# The result is >>>
# 1
# 2
# 2
# 2
# 3
# 4
# 5
# 5
# 5
# 6
# ...
